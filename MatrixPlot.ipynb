# %%
# Cargamos el archivo
filename = './rvvcca_d_horarios_2021-2022.csv'

import pandas as pd

data = pd.read_csv(filename, sep=";")
data.shape
# Out:
# (201480, 30)

# %%
mediciones = data.iloc[:, 7:13]
mediciones.head()
# Out:
#    pm2_5  pm10   no  no2   nox    o3
# 0    6.0   7.0  2.0  3.0   6.0  91.0
# 1    6.0   7.0  1.0  4.0   6.0  86.0
# 2    9.0  10.0  2.0  3.0   5.0  74.0
# 3    8.0   8.0  2.0  9.0  11.0  65.0
# 4    2.0   3.0  2.0  8.0  11.0  82.0

# %% [markdown]
# Vamos a crear una matriz de gráficos de puntos **scatterplot matrix** seis a partir de las cinco primeras características. Las matrices de gráficos de puntos muestran un histograma de cada característica en la diagonal y los gráficos de puntos, para cada par de características del juego de datos. Nos proporciona de un modo esquemático una visualización muy general de nuestros datos.

# %%
# En este comando le decimos al notebook que muestre los gráficos dentro del propio notebook
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(mediciones);
